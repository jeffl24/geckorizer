# %%
import requests
import json
import numpy as np
import pandas as pd
import pprint

# %%
url = 'https://api.tradegecko.com/orders'
bearer = {'Authorization': 'Bearer f4855aebc4a92c0d6a09f07b105bcbae81afbaf8cb1344f47a5b5c45cf8f4c1e'}

r = requests.get(url, headers=bearer).text
r
# Out:
# '{"orders":[{"id":30652187,"created_at":"2018-03-02T05:34:19.356Z","updated_at":"2018-03-02T05:34:20.014Z","assignee_id":null,"billing_address_id":26734790,"company_id":17485464,"contact_id":9590837,"currency_id":64483,"shipping_address_id":26734790,"stock_location_id":87144,"user_id":73080,"default_price_list_id":"retail","document_url":"https://go.tradegecko.com/d/WmYZ5VetG4ZZihAKLJxoOYfE","email":"fayinn427@gmail.com","fulfillment_status":"unshipped","invoice_status":"invoiced","issued_at":"2018-03-02","notes":"","order_number":"191569915487","packed_status":"unpacked","payment_status":"paid","phone_number":"84267104\u202c","reference_number":null,"return_status":"unreturned","returning_status":"unreturning","ship_at":"2018-03-02","source_url":"https://paulas-choice-singapore.myshopify.com/admin/orders/366266712129","status":"finalized","tax_label":"GST","tax_override":null,"tax_treatment":"exclusive","total":"59.0","tags":[],"fulfillment_ids":[],"fulfillment_return_ids":[],"invoi
# ...

# %%
json.loads(requests.get('https://data.gov.in/node/305681/datastore/export/json').text)
# Out:
# {'data': [['1',
#    'Andhra Pradesh',
#    '183446.36',
#    '193958.45',
#    '201277.09',
#    '212103.27',
#    '222973.83'],
#   ['2', 'Arunachal Pradesh', '360.5', '380.15', '407.42', '419', '438.69'],
#   ['3', 'Assam', '4658.93', '4671.22', '4707.31', '4705', '4709.58'],
#   ['4', 'Bihar', '10740.43', '11001.77', '7446.08', '7552', '8371.86'],
#   ['5',
#    'Chhattisgarh',
#    '9737.92',
#    '10520.01',
#    '12454.34',
#    '12984.44',
#    '13704.06'],
#   ['6', 'Goa', '148.61', '148', '149', '149.45', '457.87'],
#   ['7', 'Gujarat', '12675.35', '12761.98', '13269.23', '14269.19', '14558.39'],
#   ['8', 'Haryana', '38149.81', '38453.06', '39644.17', '41141.91', '42342.66'],
#   ['9',
#    'Himachal Pradesh',
#    '977.3',
#    '1000.26',
#    '1020.62',
#    '1049.66',
#    '1069.39'],
#   ['10',
#    'Jammu and Kashmir',
#    '7208.26',
#    '7242.01',
#    '7725.19',
#    '6519.8',
#    '6715.41'],
# ...

# %%
d = json.loads(requests.get(url, headers=bearer).text)
d
# pd.DataFrame(d["meta"], columns=[x["meta"] for x in d["orders"]])
# Out:
# {'meta': {'total': 14668},
#  'orders': [{'assignee_id': None,
#    'billing_address_id': 26734006,
#    'company_id': 21144064,
#    'contact_id': None,
#    'created_at': '2018-03-02T04:39:51.492Z',
#    'currency_id': 64483,
#    'default_price_list_id': 'retail',
#    'default_price_type_id': 'retail',
#    'document_url': 'https://go.tradegecko.com/d/w9A0OUGxVsDafEpFuD9ioejg',
#    'email': 'cllogam11@gmail.com',
#    'fulfillment_ids': [19561104],
#    'fulfillment_return_ids': [],
#    'fulfillment_status': 'shipped',
#    'id': 30650946,
#    'invoice_ids': [19387016],
#    'invoice_numbers': {'19387016': '191569915485'},
#    'invoice_status': 'invoiced',
#    'invoices': [{'id': 19387016, 'invoice_number': '191569915485'}],
#    'issued_at': '2018-03-02',
#    'notes': '',
#    'order_line_item_ids': [86800908],
#    'order_number': '191569915485',
#    'packed_status': 'packed',
#    'payment_ids': [16412531],
#    'payment_status': 'paid',
#    'phone_number': None,
# ...

# %%
df = pd.read_json(path_or_buf=r) #, orient='records')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-e75aedddafd0> in <module>()
# ----> 1 df = pd.read_json(path_or_buf=r) #, orient='records')
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines)
#     352         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     353                           keep_default_dates, numpy, precise_float,
# --> 354                           date_unit).parse()
#     355
#     356     if typ == 'series' or obj is None:
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\io\json\json.py in parse(self)
#     420
#     421         else:
# --> 422             self._parse_no_numpy()
#     423
#     424         if self.obj is None:
#
# ...

# %%
df = pd.DataFrame.from_dict(pd.io.json.json_normalize(r)) #, orient='columns')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-b0bb0a365104> in <module>()
# ----> 1 df = pd.DataFrame.from_dict(pd.io.json.json_normalize(r).text) #, orient='columns')
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     181
#     182     if record_path is None:
# --> 183         if any([isinstance(x, dict) for x in compat.itervalues(data[0])]):
#     184             # naive normalization, this is idempotent for flat records
#     185             # and potentially will inflate the data considerably for
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\compat\__init__.py in itervalues(obj, **kw)
#     182
#     183     def itervalues(obj, **kw):
# --> 184         return iter(obj.values(**kw))
#     185
#     186     next = next
#
# ...

# %%
pd.io.json.json_normalize(r, record_path='id', meta=["order_number", ["invoices", "invoice_number", 'invoice_status']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-9eeef3e9ba31> in <module>()
# ----> 1 pd.io.json.json_normalize(r, record_path='id', meta=["order_number", ["invoices", "invoice_number", 'invoice_status']])
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     246                 records.extend(recs)
#     247
# --> 248     _recursive_extract(data, record_path, {}, level=0)
#     249
#     250     result = DataFrame(records)
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in _recursive_extract(data, path, seen_meta, level)
#     223         else:
#     224             for obj in data:
# --> 225                 recs = _pull_field(obj, path[0])
#     226
#     227                 # For repeating the metadata later
#
# ...

# %%
p = json.loads(requests.get(url, headers=bearer).text)

# %%
# list(p['orders'])

import collections

result = collections.defaultdict(list)
for d in list(p['orders']):
    result[d['billing_address_id']].append(d)

result_list = result.values()

# %%
result
# Out:
# defaultdict(list,
#             {13168596: [{'assignee_id': None,
#                'billing_address_id': 13168596,
#                'company_id': 10887004,
#                'contact_id': None,
#                'created_at': '2018-03-02T04:33:59.413Z',
#                'currency_id': 64483,
#                'default_price_list_id': 'retail',
#                'default_price_type_id': 'retail',
#                'document_url': 'https://go.tradegecko.com/d/KmaAfrxsA-ncA08Nj7nLlCWn',
#                'email': '',
#                'fulfillment_ids': [19561000],
#                'fulfillment_return_ids': [],
#                'fulfillment_status': 'shipped',
#                'id': 30650793,
#                'invoice_ids': [19386871],
#                'invoice_numbers': {'19386871': '191569914-1856'},
#                'invoice_status': 'invoiced',
#                'invoices': [{'id': 19386871,
#                  'invoice_number': '191569914-1856'}],
# ...

# %%
pd.DataFrame(p['orders'], columns=[x['label'] for x in p['orders']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-3cfbd0448fc3> in <module>()
# ----> 1 pd.DataFrame(p['orders'], columns=[x['label'] for x in p['orders']])
#
# <ipython-input-60-3cfbd0448fc3> in <listcomp>(.0)
# ----> 1 pd.DataFrame(p['orders'], columns=[x['label'] for x in p['orders']])
#
# KeyError: 'label'
