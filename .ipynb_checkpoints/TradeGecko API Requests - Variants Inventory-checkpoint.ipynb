# %%
import requests
import json
import numpy as np
import pandas as pd
import pprint
pd.options.display.max_columns = 999

# %%
url = 'https://api.tradegecko.com/orders'
bearer = {'Authorization': 'Bearer f4855aebc4a92c0d6a09f07b105bcbae81afbaf8cb1344f47a5b5c45cf8f4c1e'}

orders_request = requests.get(url, headers=bearer).text
orders_json = json.loads(requests.get(url, headers=bearer).text)
orders_df = pd.io.json.json_normalize(d, record_path='orders')
orders_df
# only gives most recent 100 transactions though
# pd.DataFrame(d["meta"], columns=[x["meta"] for x in d["orders"]])
# Out:
# '{"orders":[{"id":31783759,"created_at":"2018-04-06T04:53:14.973Z","updated_at":"2018-04-06T04:53:15.579Z","assignee_id":null,"billing_address_id":22714399,"company_id":15347643,"contact_id":7640375,"currency_id":64483,"shipping_address_id":22714399,"stock_location_id":87351,"user_id":73080,"default_price_list_id":"retail","document_url":"https://go.tradegecko.com/d/CGmQ6sad5p-bWv2Y1gSSzhPO","email":"diana.quek@yahoo.com.sg","fulfillment_status":"shipped","invoice_status":"invoiced","issued_at":"2018-04-06","notes":"","order_number":"191569916689","packed_status":"packed","payment_status":"paid","phone_number":"9299 8162","reference_number":null,"return_status":"unreturned","returning_status":"unreturning","ship_at":"2018-04-06","source_url":"https://paulas-choice-singapore.myshopify.com/admin/orders/464910516289","status":"fulfilled","tax_label":"GST","tax_override":null,"tax_treatment":"exclusive","total":"38.0","tags":[],"fulfillment_ids":[20513919],"fulfillment_return_ids":[],"in
# ...

# %%
variant_inventory_url = 'https://api.tradegecko.com/variants'
bearer = {'Authorization': 'Bearer f4855aebc4a92c0d6a09f07b105bcbae81afbaf8cb1344f47a5b5c45cf8f4c1e'}

variant_inventory_request = requests.get(variant_inventory_url, headers=bearer).text
variant_inventory_json = json.loads(variant_inventory_request)
variant_inventory_df = pd.io.json.json_normalize(variant_inventory_json, record_path=['variants'])
variant_inventory_df
# Out:
#    buy_price committed_stock             committed_stock_levels  composite  \
# 0       None              30                  {'87144': '30.0'}      False
# 1        2.1               0                                 {}       True
# 2        2.1               0                                 {}       True
# 3       0.42               0                                 {}      False
# 4       0.42               0                                 {}      False
# 5       0.42               0                                 {}      False
# 6        6.0               3                   {'87144': '3.0'}      False
# 7      28.98               7   {'87144': '1.0', '87350': '6.0'}      False
# 8      13.57               0                                 {}       True
# 9      90.06              23  {'87144': '21.0', '87350': '2.0'}       True
# 10     40.88               3                   {'87144': '3.0'}       True
# ...

# %%
variant_inventory_df['prices'][99]
# Out:
# {'18772': '0.0000',
#  '18773': '0.0000',
#  '18774': '0.0000',
#  '19651': '0.0000',
#  'buy': '0.0',
#  'retail': '1.5',
#  'wholesale': '0.75'}

# %%
variant_inventory_df = pd.io.json.json_normalize(variant_inventory_json, record_path='variants')
variant_inventory_df
# Out:
#    meta.total                                           variants
# 0         310  [{'id': 38874604, 'created_at': '2018-03-29T07...

# %%
product_master_url = 'https://api.tradegecko.com/products/'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-b0bb0a365104> in <module>()
# ----> 1 df = pd.DataFrame.from_dict(pd.io.json.json_normalize(r).text) #, orient='columns')
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     181
#     182     if record_path is None:
# --> 183         if any([isinstance(x, dict) for x in compat.itervalues(data[0])]):
#     184             # naive normalization, this is idempotent for flat records
#     185             # and potentially will inflate the data considerably for
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\compat\__init__.py in itervalues(obj, **kw)
#     182
#     183     def itervalues(obj, **kw):
# --> 184         return iter(obj.values(**kw))
#     185
#     186     next = next
#
# ...

# %%
pd.io.json.json_normalize(r, record_path='id', meta=["order_number", ["invoices", "invoice_number", 'invoice_status']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-9eeef3e9ba31> in <module>()
# ----> 1 pd.io.json.json_normalize(r, record_path='id', meta=["order_number", ["invoices", "invoice_number", 'invoice_status']])
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     246                 records.extend(recs)
#     247
# --> 248     _recursive_extract(data, record_path, {}, level=0)
#     249
#     250     result = DataFrame(records)
#
# C:\Users\limzi\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in _recursive_extract(data, path, seen_meta, level)
#     223         else:
#     224             for obj in data:
# --> 225                 recs = _pull_field(obj, path[0])
#     226
#     227                 # For repeating the metadata later
#
# ...

# %%
p = json.loads(requests.get(url, headers=bearer).text)

# %%
# list(p['orders'])

import collections

result = collections.defaultdict(list)
for d in list(p['orders']):
    result[d['billing_address_id']].append(d)

result_list = result.values()

# %%
result
# Out:
# defaultdict(list,
#             {13168596: [{'assignee_id': None,
#                'billing_address_id': 13168596,
#                'company_id': 10887004,
#                'contact_id': None,
#                'created_at': '2018-03-02T04:33:59.413Z',
#                'currency_id': 64483,
#                'default_price_list_id': 'retail',
#                'default_price_type_id': 'retail',
#                'document_url': 'https://go.tradegecko.com/d/KmaAfrxsA-ncA08Nj7nLlCWn',
#                'email': '',
#                'fulfillment_ids': [19561000],
#                'fulfillment_return_ids': [],
#                'fulfillment_status': 'shipped',
#                'id': 30650793,
#                'invoice_ids': [19386871],
#                'invoice_numbers': {'19386871': '191569914-1856'},
#                'invoice_status': 'invoiced',
#                'invoices': [{'id': 19386871,
#                  'invoice_number': '191569914-1856'}],
# ...

# %%
pd.DataFrame(p['orders'], columns=[x['label'] for x in p['orders']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-3cfbd0448fc3> in <module>()
# ----> 1 pd.DataFrame(p['orders'], columns=[x['label'] for x in p['orders']])
#
# <ipython-input-60-3cfbd0448fc3> in <listcomp>(.0)
# ----> 1 pd.DataFrame(p['orders'], columns=[x['label'] for x in p['orders']])
#
# KeyError: 'label'
